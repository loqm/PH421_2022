# %% [markdown]
# $\huge Development$ $\huge of$ $\huge a$ $\huge simple$ $\huge model$ $\huge for$ $\huge optical$ $\huge parametric$ $\huge generation$

# %% [markdown]
# $ Abhishek$ $Anand,$ $Kapil$ $Bhagat, Nirmal$ $Solanki$, $Bhavya$ $Singhal$, $Parmy$ $Uttam$

# %% [markdown]
# # Table  of Content
# * Abstract
# * Introduction
# * Critical  Length for Parametric Generation
# * Developing  the Theoretical Model
# * Experimental Setup
# * Conclusion
# * References
# * Indiviual Contribution

# %% [markdown]
# $\large Abstract$
#
# Optical parametric generation is treated as a particular case of parametric amplification of two waves at frequencies 𝜔1 and 𝜔2 from a pump wave 𝜔3 propagating in a nonlinear crystal configuration in which initial intensities for 𝜔1 and 𝜔2 at the input plane of the material are equal to zero. This research is based on the theory of optical parametric fluorescence. According to the quantum-mechanical model, there is a probability for a photon 𝜔3 to be spontaneously scattered into photons ℏ𝜔1 and ℏ𝜔2, respectively. We introduce a critical length over which the first signal and idler photons are created. This new approach allows us to take into account optical parametric fluorescence not only at the entrance of material but also over its entire interaction length. We show that this can widely modify the calculated generated intensities. This model is applied to a KTP optical parametric generator and amplifier pumped by the second harmonic (532 nm) of a Nd:YAG picosecond laser.

# %% [markdown]
# $\large Introduction $
#
# Optical parametric oscillators generate a second-order nonlinear process that involves three optical frequencies: the pump, signal, and idler frequencies. An incident laser pump beam is first focused into a nonlinear crystal. The light field of the pump beam will generate multiple fields due to variances in the crystal’s refractive index. The generated field with higher frequency is referred to as the signal while the lower frequency field is called the idler.  The pump, signal, and idler waves interact such that the signal and idler waves amplify while the pump wave weakens. The created gain allows the resonant waves (either the signal, idler, or both) to oscillate within the resonator. The OPO is described as singly resonant when the cavity is matched to either the pump, signal or idler frequency. The system is doubly resonant when two are set to resonate together.Several authors developed a quantum-mechanical model that describes the first-generated photons as being emitted spontaneously from pump photons at the entrance plane of the crystal. This process is known as optical parametric fluorescence (OPF). Thus OPF provides the first photons that will take part in parametric amplification. Although OPF has been clearly described and observed experimentally, the number of noise photons—considered as the source for the parametric amplification—has been the subject of different approaches based on assumptions that are not clearly justified physically. We have developed a simple model in which the relation between pump and noise photons is clearly defined. By taking into account the probability for a pump photon to be emitted spontaneously into a signal photon and an idler photon, we defined a critical length by analogy with laser amplification into a medium.
# This is the length over which N photons produce one photon at each generated frequency. The two photons produced over that critical length are then taken as signal and idler input intensities for parametric amplification over the remaining distance in the crystal. Then we further developed our theoretical model by including OPF not only at the entrance plane of the crystal but also over the entire photon path in the crystal. We demonstrate that since noise
# photons are not negligible in comparison to signal and idler intensities, OPF has to be considered in parametric interactions.

# %% [markdown]
# ![6-Figure3-1.png](data:image/png;base64,...)

# %% [markdown]
# $\large Critical$ $\large Length$ $\large for$ $\large Parametric$ $\large Generation $

# %% [markdown]
# In the classical description of parametric interactions between three waves propagating in a nonlinear media, the variation of the amplitude Eᵢ and the phase of each wave (i=1, 2, 3) over a finite element of length δz is proportional to the product of amplitudes of the two other waves:
#
# $𝚫Eᵢ/𝚫z ∝ EⱼEₖ$
#
# We need to consider the waves generated in the start as noise photons because Optical Parametric Generation needs 2 out of 3 intitial amplitudes as zero.
#
# In general, in the parametric process, a photon at $ω_{3}$ is scattered into a photon at $ω_{1}$ and a photon at $ω_{2}$ with $ω_{1}+ω_{2}=ω_{3}$ and $k_{1}+k_{2}=k_{3}$. This nonlinear optical emission can be properly described only by quantizing the fields.
#
#
#
# Using Quantization of Cavity modes, we get field Hamiltonian as
#
# $Hₒ = \frac{1}{2}∑_{l}[p_{l}^{2}+ω_{l}^{2}q_{l}^{2}]$
#
# where
#
# $\frac{dq_{l}}{dt}=p_{l}$
#
# We now quantize by regarding the $p_{l}$ and $q_{l}$ as the Hermitian operators satisfying the commutation relations
#
# $ [p_{l},p_{m}]=[q_{l},q_{m}]=0; [q_{l},p_{m}]=ih'δ_{lm}.$
#
# The operators $p_{l}$ and $q_{l}$ may be expressed in terms of non-hermitian $a_{l}^{t}$ and $a_{l}$ by means of
#
#   $ q_{l}(t)=(\frac{ħ}{2ω_{l}})^{\frac{1}{2}}[a_{l}^{†}(t)+a_{l}(t)]$,
#
#   $ p_{l}(t)=(\frac{ħω_{l}}{2})^{\frac{1}{2}}[a_{l}^{†}(t)+a_{l}(t)]$,
#
#   where $a_{l}^{t}$ is the Hermitian conjugate of $a_{l}$. The a's obey the commutation relations
#
#   $[a_{l}(t),a_{m}^{t}(t)]=δ_{lm}$;
#
#   $[a_{l}(t),a_{m}(t)]=$$[a_{l}^{†}(t),a_{m}^{†}(t)]=0$
#
#   In terms of the a's, the Hamiltonian becomes
#
#   $H_{o}=∑_{l} ħω_{l}[a_{l}^{†}a_{l}+\frac{1}{2}]$
#
# In order to provide coupling among the various cavity modes, we assume that the dielectric constant varies as
#
# $ϵ(r,t)=1+𝚫ϵcos(ωt+ϕ)f(r)$,
#
# The weak coupling approximation assumes that $𝚫ϵ<<1$. $ϕ$ is an arbitrary pump phase.
#
# The Hamiltonian for the system is now given by
#
# $H=\frac{1}{8π}\int_{cavity} [ϵ(r,t)E^{2}+H^{2}]\,dV$
#
#
#   $= \frac{1}{8π}\int_{cavity} [E^{2}+H^{2}]\,dV+\frac{1}{8π}\int_{cavity} ϵ'(r,t)E^{2}dV.$
#
# The first term is the unperturbed Hamiltonian of the previous section while the second term gives the coupling. If we express E and H in terms of the unperturbed cavity modes of the previous section, we can write the Hamiltonian as
#
# $ H=H_{o}+H'$
#
# where $H_{o}$ was derived earlier and
#
# $ H'(t) = -ħcos(ωt+ϕ)∑_{l,m} κ_{lm}(a_{l}^{†}-a_{l})(a_{m}^{†}-a_{m}),$
#
# Coupling coefficients are
#
# $κ_{lm}=κ_{ml}=\frac{𝚫ϵ}{16πc^{2}}(ω_{l}ω_{m})^{\frac{1}{2}}\int_{cavity} f(r)u_{l}.u_{m}\,dV.$
#
# Using Heisenberg equations of motion and commutation relations
#
# $ \frac{da_{j}^{†}}{dt} = iω_{j}a_{j}^{†}+ i[e^{i(ωt+ϕ)} + e^{-i(ωt+ϕ)}]∑_{l} κ_{jl} (a_{l}^{t} - a_{l}) $
#
# Barring accidental degeneracies, we therefore assume that only two nondegenerate modes are coupled by the pump field at ω and denotes them as the signal mode and idler mode. For ω=ω_{1}+ω_{2},
#
# $ H_{amp'}=-ħκ[a_{1}^{†}a_{2}^{†}e^{-i(ωt+ϕ)} + a_{1}a_{2}e^{i(ωt+ϕ)}] $

# %% [markdown]
# Hₒ describes the energy flow between the pump and the generated waves, while Hₘ describes the mixing between the signal and the idler. The aᵢ and $ a_{i}^{†}$ are the creation and annihilation operators for the wave at ωᵢ. Γ is defined by:
#
# $ Γ = \frac{1}{16π^{2}ϵ_{o}^{3}}(\frac{8πω_{1}ω_{2}d_{eff}^{2}I_{3}}{n_{1}^{2}n_{2}^{2}n_{3}C})^{1/2}\frac{sin(\frac{Δkl}{2})}{\frac{Δkl}{2}} $
#
# where $ d_{eff}$ is the effective nonlinear coeffient of the crystal and l is the length of the crystal. ϵₒ is the vacuum permittivity.

# %% [markdown]
# In the parametric process with negligible pump depletion, the intense pump field can be treated as a constant classical field. Tha Hamiltonian governing the problem can be written as
#
# $H = ∑ᵢ  ħωᵢ(aᵢ^{†}aᵢ + \frac{1}{2}ħΓ[a1^{†}a2^{†}e^{-iω3t} + a1a2e^{iω3t}]$
#
# The heisenberg equation of motion for an operator X is
#
# $ \frac{dX}{dt}=\frac{1}{iħ}[X,H] $
#
# The application of these equations of motion to the operators $a_{1}^{t}$ and $a_{2}$ results in
#
# $ \frac{da_{1}^{†}}{dt} = iω_{1}a_{1}^{†}+ \frac{i}{2}Γa_{2} exp(iω_{3}t) $,
#
# $ \frac{da_{2}}{dt} = -iω_{2}a_{2}- \frac{i}{2}Γa_{1}^{t} exp(-iω_{3}t) $
#
# Solving these we get,
#
# $ a_{1}^{†} = [a_{1}^{†}cosh\frac{1}{2}Γt + ia_{2}(0)sinh\frac{1}{2}Γt]e^{iω_{1}t} $
#
#
# $ a_{2} = [a_{2}cosh\frac{1}{2}Γt - ia_{1}(0)sinh\frac{1}{2}Γt]e^{-iω_{2}t} $
#
# Assuming $ <a_{1}(0)> = <a_{2}(0)>=0$, we get avegare numbers of photons at $ω_{1}$ and $ω_{2}$ as,
#
# $ <n_{1}(t)> = <a_{1}^{†}(t)a_{1}(t)> = <n_{1}(0)>cosh^{2}\frac{1}{2}Γt + (1+<n_{2}(0)>)sinh^{2}\frac{1}{2}Γt$
#
# $ <n_{1}(t)> = <a_{1}^{†}(t)a_{1}(t)> = <n_{1}(0)>cosh^{2}\frac{1}{2}Γt + (1+<n_{2}(0)>)sinh^{2}\frac{1}{2}Γt$

# %% [markdown]
# For $ <n_{1}(0) = 0 $ and $ <n_{2}(0)>=0$,
#
# $<n_{1}(t)> = <n_{2}(t)> = sinh^{2}\frac{1}{2}Γt $
#
# We can rewrite this is terms of l=Ct as
#
# $ ̅n_{1}(l) = ̅n_{2}(l) = sinh^{2}(\frac{Γl}{2C})$

# %% [markdown]
# Critical Length is defined as the length for which we can assume that among all the incident pump photons, one photon will be spontaneously emitted into one signal and idler photon.
#
# $ ̅n_{1}(l_{c}) = ̅n_{2}(l_{c}) = 1$
#
# Let's derive $l_{c}$ using this:
#
# $ sinh^{2}(\frac{Γl_{c}}{2C}) = 1 $
#
# Let $ \frac{Γl_{c}}{2C} = x $
#
# $ sinh^{2}(x) = 1 $
#
# $ (\frac{e^{x}-e^{-x}}{2})^{2} = 1 $
#
# $ e^{x} - e^{-x} = 2 $
#
# $ y^{2} - 2y - 1 = 0$
#
# $ y = \frac{2 ± \sqrt{4+4}}{2} $
#
# $  e^{x} = 1 + \sqrt{2} $
#
# $ x = \ln{(1+\sqrt{2})} $
#
# $ l_{c} = \frac{2C}{Γ} \ln{(1+\sqrt{2})} $

# %% [markdown]
# Optical parametric amplification cannot take place in nonlinear material with a length shorter than $l_{c}$. We can view this physically in the sense that the first generated photons are not located at the entrance plane of the crystal but originate from the material after a width of $l_{c}$

# %% [markdown]
# $ l_{c} = \frac{2C}{Γ} \ln{(1+\sqrt{2})} $
#
# where, $ Γ^{2} =\frac{8π^{2}d_{eff}^{2}I_{p}}{ϵ_{o}λ_{s}λ_{i}n_{p}n_{s}n_{i}c}  $
#
# Thus, $ l_{c} ∝ \sqrt{ \frac{λ_{i}}{I_{p}}} $

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.1,15,0.1)
y= 100*(np.sqrt(3)/np.sqrt(x))*np.log((1+np.sqrt(2)))   #Here we are checking for λ=3µm,2µm,1.31µm only

y1= 100*(np.sqrt(2)/np.sqrt(x))*np.log((1+np.sqrt(2)))

y2= 100*(np.sqrt(1.31)/np.sqrt(x))*np.log((1+np.sqrt(2)))

f = plt.figure()
f.set_figwidth(7)
f.set_figheight(7) 
plt.xlim(0, 15)
plt.ylim(0, 450)

plt.title("Line graph")
plt.xlabel("Intensity (GW/cm^2)")
plt.ylabel("Critical Length (µm)")
plt.plot(x, y, color ="r",label="λ=3µm")
plt.plot(x, y1, color ="g",label='λ=2µm')
plt.plot(x, y2, color ="b",label='λ=1.31µm')
plt.legend()
plt.show()

# %% [markdown]
# It has been calculated on a type II interaction (𝑜→𝑒+𝑜) in the (𝑥, 𝑧) plane of a KTP crystal, assuming a perfect angular phase-matching case (Δ𝑘=0). The pump wavelength is 532 nm. The above figure shows that for pump intensities lower than 1 GW/cm2, 𝑙𝑐 increases abruptly from 250 µm to several millimeters; i.e., reasonable values of generated intensities are barely attainable below that point. Above 1 GW/cm2, the critical length seems to be stabilized near 100 µm. Moreover, owing to the decrease of the effective nonlinear coefficient of KTP crystal. we can observe that 𝑙𝑐 increases as the idler wavelength tends toward the far infrared.

# %% [markdown]
# $ \large Developing$  $\large the$ $\large Theoretical$ $\large Model$
#
# We first derive the parametric equations using the plane wave approximation.
#
# Proceeding from Maxwell's Equations:
#
# $ \vec{Δ}$ X $\vec{E} = - \frac{δ\vec{B}}{δt} $
#
# $ \vec{𝚫}$ X $\vec{H} = \vec{J} + \frac{δ\vec{D}}{δt} $
#
# $ \vec{𝚫} . \vec{D} = 0 $
#
# $ \vec{𝚫}. \vec{B} = 0 $
#
# and
#
# $ \vec{D} = ϵ_{o}ϵ\vec{E} + \vec{P} $
#
# $ \vec{B} = μ_{o}\vec{H} $
#
# The medium is assumed to be magnetically inactive. The fields obey the wave equation
#
# $ \frac{δ^{2}E}{δz^{2}} - μ_{o}σ\frac{δE}{δt} - μ_{o}ϵ_{o}ϵ\frac{δ^{2}E}{δt^{2}} = μ_{o}\frac{δ^{2}P}{δt^{2}} $
#
# The nonlinear interactions occurs over distances and times that are large w.r.t the individual sinusoidal variations of optical fields
#
# $ E_{i}(z,t) = ∑_{m} R_{e}(E_{im} exp j(ω_{m}t - k_{m}z)) $
#
# $ P_{i}(z,t) = ∑_{m} R_{e}(P_{im} exp j(ω_{m}t - k_{m}z)) $
#
# Plug these equations into the wave equation to get:
#
# $ \frac{δE_{m}}{δz} + (n_{m}/c)\frac{δE_{m}}{δt} + α_{m}E_{m} = -j\frac{μ_{o}cω_{m}}{2n_{m}}P_{m} $
#
# where $ n_{m} = (ϵ_{m})^{1/2} $ and $ α_{m}E_{m} = \frac{1}{2}μ_{o}σc/n_{m} $ is the electric field loss factor.
#
# The envelope representation applied to nonlinear polarization components gives
#
# $ P_{1} = 2ϵ_{o}d_{eff}E_{2}^{*}E_{3}e^{-j𝚫kz} $
#
# $ P_{2} = 2ϵ_{o}d_{eff}E_{1}^{*}E_{3}e^{-j𝚫kz} $
#
# $ P_{3} = 2ϵ_{o}d_{eff}E_{1}E_{2}e^{+j𝚫kz} $
#
# Substituting these in earlier generated equation:
#
# $ \frac{δE_{1}}{δz} + \frac{n_{1}}{c}\frac{δE_{1}}{δt} + α_{1}E_{1} = -j\frac{ω_{1}d_{eff}}{n_{1}c}E_{2}^{*}E_{3}e^{-jδkz} $
#
# $ \frac{δE_{2}}{δz} + \frac{n_{2}}{c}\frac{δE_{2}}{δt} + α_{2}E_{2} = -j\frac{ω_{2}d_{eff}}{n_{2}c}E_{1}^{*}E_{3}e^{-jδkz} $
#
# $ \frac{δE_{3}}{δz} + \frac{n_{3}}{c}\frac{δE_{3}}{δt} + α_{3}E_{3} = -j\frac{ω_{3}d_{eff}}{n_{3}c}E_{1}E_{2}e^{+jδkz} $

# %% [markdown]
# where σ denotes the linear losses in the crystal. Walk-off angles between wave vectors and Poynting vectors are neglected.
#
# Furthermore, it will be convenient to take $ E_{i} = ρ_i exp(-jΦ_i) $, where $ρ_i$ is the real amplitude and $ Φ_i$ is the phase of the wave $ω_i$.

# %% [markdown]
# Using the above formulaes, we get:
#
# $ \frac{du_{1}}{dζ} = n_{1}u_{1} - u_{2}u_{3} sin θ $
#
# $ \frac{du_{2}}{dζ} = n_{2}u_{2} - u_{1}u_{3} sin θ $
#
# $ \frac{du_{3}}{dζ} = n_{3}u_{3} + u_{1}u_{2} sin θ $
#
# $ \frac{du_{1}}{dζ} = K + (\frac{u_{1}u_{2}}{u_{3}} - \frac{u_{2}u_{3}}{u_{1}} - \frac{u_{1}u_{3}}{u_{2}}cos θ $
#
#
# The variables u_{i} are normalized variables for wave intensities:
#
# $ u_{i} = (\frac{I_{i}}{ω_{i}P})^{1/2} $
#
# According to Boyd,
#
# $ ζ = z/l $
#
# where
#
# $ l = \frac{(n_{1}n_{2})^{1/2}c}{2ω_{1}d_{eff}|A_{1}(0)|} $
#
# Using these equations we get,
#
# $ ζ = \frac{4π^{3/2}d^{eff}P^{1/2}}{(ϵ_{0}λ_{1}λ_{2}λ_{3}n_{1}n_{2}n_{3})^{1/2}}z $
#
# P denotes the total incident intensity:
#
# $ P = I_{1}(0) + I_{2}(0) + I_{3}(0) $
#
# K is given by
#
# $ K = (Δk/ζ)z $
#
# and
#
# $ n_{i} = (\frac{ϵ_{0}λ_{i}n_{i}}{4πPζ^{2}})^{1/2}σ $

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.1,3,0.1)
y =1/np.cosh(x)
y1 =np.tanh(x)
plt.plot(x, y, color ="c",label="u1")
plt.plot(x, y1, color ="b",label="u2")
plt.xlabel("normalized propagation distance ζ=z/l ")
plt.ylabel("normalized field amplitude")
plt.legend()
plt.show()

# %% [markdown]
# Parametric Scattering implies a quantum description of the nonlinear process because the signal and the idler fields are at the zero-photon level. Therefore, we treat parametric generation separately from parametric amplification.

# %% [markdown]
# $\large Experimental$ $\large Setup$

# %% [markdown]
# ![Screenshot 2022-10-29 164435.png](data:image/png;base64,...)

# %% [markdown]
# The majority of OPO's are pumped with a Q-Switched laser. The pulse from the laser emit on the order of nanoseconds, allowing the system to easily overcome the threshold for oscillation and also the researchers can use mode-locked laser's to pump OPO's and produce ultrashort pulses of light . The frequency within the resonator or these oscillator matches the pulse repetition rate of the pump.
# A 50:50 beam splitter divides the pump pulse into two components , here in the experimental setup the distance between the  two flux-grown KTP crystals used here is 6 mm long. They are cut in the (x, z) plane (θ=0°) for a type II (o  - e + o) configuration. Because the two KTP crystals are separated by 20 cm, only the central part of the generated pulses overlap the pump pulse in the second crystal and participate in the amplification. The portion of the pump pulse reflected by the beam splitter passes through the crystal first, producing signal (p-polarized) and idler (s-polarized) pulses. The pulses are then reflected back and amplified by the second part of the pump, which is properly delayed, through the same crystals.

# %% [markdown]
# In case of KTP Type-II interaction, where signal and idler waves
# are orthogonally polarized, the efficient nonlinear coefficient $d_{eff}$ is
# expressed by:
#
# $d_{eff}$ (II) ≈  -($d_{15}sin^{2}ϕ + d_{24}cos^{2}ϕ)sinΘ$
#
#
# The KTP nonlinear coefficients $d_{ij}$ values are as follows:
#
# $d_{15}$ = 1.91 pm/V
#
# $d_{24}$ = 3.64 pm/V
#
# $d_{31}$ = 2.54 pm/V
#
# $d_{32}$ = 4.35 pm/V
#
# $d_{33}$ = 16.9 pm/V

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,np.pi/4,0.01)
y= (1.91*np.sin(x)*np.sin(x)+3.64*np.cos(x)*np.cos(x))

f = plt.figure()
f.set_figwidth(10)
f.set_figheight(7) 

plt.title("Line graph")
plt.xlabel("Crystal Orientation(deg)")
plt.ylabel("deff(pm/V)")
plt.plot(x, y, color ="c",label="deff")
plt.legend()
plt.show()

# %% [markdown]
# ![Screenshot (975).png](data:image/png;base64,...)

# %% [markdown]
# The generated signal and idler wavelength satisfy the two collinear phase matching conditions involving energy and momentum conservation:
#
# $ \frac{1}{λ_{p}} = \frac{1}{λ_{s}} + \frac{1}{λ_{i}}, \frac{n_{p}}{λ_{p}}=\frac{n_{s}}{λ_{s}} + \frac{n_{i}}{λ_{i}}$
#
# where λ and n denote the wavelength and the refractive indices seen by the propagating pulses.
#
# The refractive indices are calculated from a modified form of the Sellmeier equations given by
#
# $ n^{2} = A + \frac{B}{λ^{2}-C} - Dλ^{2} $

# %% [markdown]
# $\large Conclusion :$
#
# We have investigated a new method for simulating optical parametric generation. We considered that initially generated photons were scattered by pump photons over a length defined as the critical length. This approach does not contain any other assumptions that are difficult to justify (such as, for instance, the number of initial noise photons that we have to consider as an initial parameter for parametric amplification) and requires only knowledge of the characteristics of the pump beam and the nonlinear crystal. Moreover, we have demonstrated that if optical parametric fluorescence is the physical phenomenon that gives rise to the initial signal and idler photons, it cannot be disregarded in parametric amplification. As evidence, a certain probability for a pump photon to scatter spontaneously into one photon in each mode exists over the whole length of interaction. We have shown that a part of the photons created by optical parametric fluorescence can widely enhance the total generated output energy as long as these photons are sufficiently amplified by pump pulses. The validity of the method was tested by comparison of the computational results with experimental data provided by a picosecond KTP optical parametric generator and amplifier. We observed a reasonably good agreement with experimental results. A more complete theoretical description of our picosecond optical parametric generator and amplifier is in progress. This method can be further developed to apply to different optical parametric devices and to consider special cases, such as the phase-mismatch case.
