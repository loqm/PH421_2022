# %% [markdown]
# # **Bistable all-optical devices based on nonlinear epsilon-near-zero (ENZ) materials.**

# %% [markdown]
# ### **Introduction**
#
# Bistability is a property of system that exhibits two stable states. It rests one of those states depending on history of the system. It is the underlying principle for switching logic and storage applications. There were many electronic and magnetic bistable devices but in optical domain there is no device with acceptable characteristics(fast speed,low power,wide optical bandwidth). Most of proposed devices are based on combination of non-linear optical material and a resonant cavity. These require high power for switching and often incompatible with integrated photonics. Lack of reliable bistable optical devices prevent the technological in both conventional and quantum optics.
#
# Now with the use of Epsilon-Near-Zero (ENZ) material properties, we can make up a device which doesn't have a resonator, enabling broadband operation, and operate at sub-ps switching speed.

# %% [markdown]
# ### **Epsilon-Near-Zero Materials**
#
# As name suggests, these are optical non linear materials which has very low value of dielectric permittivity. This property makes us to manipulate and control the progation of radiation on subwavelength level.
#
# Unique properties for ENZ materials are:
#
# **1.Large refractive index tuning:**
#
# **2.Enhanced harmonic generation**
#
# **3.Near unity generation of phase conjugate waves**
#
# Transparent oxides possess two salient features which makes them different from other non-linar optical materials.
#
# **1.High degree of electric field confinement**
#
# **2.Ideal balance of strength and speed**
#
# For ENZ materials, enchancement of nonlinearity related to dielectric constant as
#
#
# $$n=𝜀^{1/2}$$
#
# $$δn \sim δ𝜀/2n$$
#
# When the permittivity is reduced, a small change results in a large change in refractive index.
#
# The change of dielectric constant is given by
# $$δε ∼ χ^{(3)}E^{2} $$
#
# where χ(3) is third-order nonlinear susceptibility.
#
# The electric field is related to the intensity of light I as
#
# $$I = nE^{2} /2η_{0}$$ where $η_{0}$ is the vacuum impedance.
#
# Therefore $$δn ∼ (χ^{(3)}η_{0}/n^{2} )I ∼ n_{2}I$$
#
# With these points in mind, we can consider the enhancement of nonlinearity in ENZ having two factors – intrinsic (or material) $χ^{(3)}$, and extrinsic $1/n^{2}$.

# %% [markdown]
# ##Momentum Dependent Mass
# The pump energy is absorbed by the free carriers, raising their kinetic energy and the electron temperature $T_{e}$. The average effective mass depends on the occupied state distribution $ρ(E)^{.}f(E)$. As the distribution of carriers shifts to higher energy states, the average effective mass of the electron sea tends to increase. This in turn, causes a decrease in the plasma frequency and a corresponding increase in dielectric constant.
#
# Now to derive the momentum dependent mass of the electron, we consider how the momentum of electrons at the Fermi surface change due to an applied electric field F. Here, the field shifts the Fermi-surface in k-space, producing a change in momentum that for some state k is given by:
# $$
# δ\textbf{k} = -\frac{e\textbf{F}}{\hbar}
# $$
# For a field applied along the z-direction, the velocity associated with a particular momentum state becomes:
# $$
# v_{z} = v_{F}cosθ = v_{F}\frac{k_{z}}{\sqrt{k^{2}_{z}+ k^{2}_{\perp} }}
# $$
# where θ is the angle between state $k$ and the axis of the applied field, in this case, the z-axis. We can then introduce the effective mass of the electron, described by the rate of change of the velocity versus the rate of change of the momentum, $dv/dk$. Thus, when we take the full-derivative with respect to $k_{z}$ we obtain:
# $$
# \frac{dv_{z}}{dk_{z}} = \frac{dv(k)}{dk}cos^{2}θ + \frac{v(k)}{k}sin^{2}\theta
# $$
# Then averaging over the polar angle, and taking into account that the field is harmonic, we obtain:
# $$
# \delta{v_{z}} = -\frac{e}{i\omega\hbar}\left[\frac{2}{3} \frac{v(k)}{k}+\frac{1}{3} \frac{d v(k)}{d k}\right]F = -\frac{e}{i\omega m^{*}(k)}F
# $$
# where:
# $$m^{*}(k)=\hbar\left[\frac{2}{3} \frac{v(k)}{k}+\frac{1}{3} \frac{d v(k)}{d k}\right]^{-1}
# $$
# The above expression gives us the momentum dependent mass of the electron.

# %% [markdown]
# ### **Average Effective Mass of the Electron**
#
#
# The effective mass of the electron sea can be calculated by averaging the effective mass of each electron $m(E)$ across all the energy states. The distribution is given by the Fermi-Dirac probability $f\left(E, \mu, T_{e}\right)$.
#
# $$m_{a v g}^{*}=\left[\frac{1}{N V} \sum_{l=1}^{n_{c a r}} \frac{1}{m^{*}\left(k_{l}\right)}\right]^{-1}$$
# For continuous energy band, it's given as follows:
# $$
# {m_{ {avg}}^{*}}=\frac{1}{N} \int \frac{f\left(E, \mu, T_{e}\right)}{m^{*}(E)} \rho(E) d E
# $$
# The expression for Fermi-Dirac distribution is:
# $$
# f\left(E, \mu, T_{e}\right)=\left[\exp \left(\frac{E-\mu}{k_{B} T_{e}}\right)+1\right]^{-1}
# $$
# where $f\left(E, \mu, T_{e}\right)$ is the Fermi-Dirac distribution, N is the carrier concentration, and $\rho(E)$ is the density of states calculated earlier.
# The applied intensity can modify the the chemical potential $\mu$ and the electron temperature $T_{e}$. Hence the appropriate expression for the intensity dependent effective mass is:
# $$
# {m_{ {avg}}^{*}(I)}=\int \frac{f\left(E, \mu(I), T_{e}(I)\right)  \rho(E)}{m^{*}(E)} d E
# $$

# %% [markdown]
# ##Dependence of Permitivity on Frequency
#
#
# The optical response of the material under an applied field of arbitrary frequency is calculated by summing the induced
# displacements for all electrons in the gas, $z(t) = -i\omega^{-1}v(t)$, as:
#
# $$
# \varepsilon(\omega)=\varepsilon_{\infty}-\frac{q^{2}}{\varepsilon_{0}\left(\omega^{2}+i \omega \Gamma\right)} \frac{1}{V} \sum_{l=1}^{n_{c a r}} \frac{1}{m^{*}\left(k_{l}\right)}=\varepsilon_{\infty}-\frac{N q^{2}}{\varepsilon_{0}\left(\omega^{2}+i \omega \Gamma\right) m^{*}_{avg}}
# $$
#
# This the generalized Drude formula for non-parabolic bands, where $Γ$ is the scattering rate, l is an occupied state, and $n_{car}$ is the number of carriers in the volume V. The dependence on intensity comes from the change in average effective mass, hence the dependence of effective mass on intensity must be calculated first.
#
# When an external pump is applied, for any given pump intensity, the distribution of carriers described through the Fermi-Dirac
# probability can be found using conservation identities of charge and energy. Firstly, the total number of carriers in the band must remain constant
#
# $$
# \int f\left(E, \mu(I), T_{e}(I)\right) \rho(E) d E=N$$
#
#
# Secondly, the total change in energy of the electron gas must be equal to the absorbed energy from the pump
#
# $$
# \int f\left(E, \mu(I), T_{e}(I)\right) E \rho(E) d E-\int f\left(E, \mu_{0}, T_{0}\right) E \rho(E) d E=\delta \mathcal{U}_{a b s}=A I \tau / d
# $$
#  ;    where $\mu_{0}$ and $T_{0}$ are the chemical potential and the electron temperature before pumping. $\tau$ is given by the electron relaxation time.
#
#
#
# The above two conditions must be satisfied for any given intensity. Hence, the chemical potential and electron temperature can be unquely defined for any given intensity. This enables us to calculate the intensity dependent effective mass as discussed earlier:
#
# $$
# {m_{ {avg}}^{*}(I)}=\int \frac{f\left(E, \mu(I), T_{e}(I)\right) \rho(E)}{m^{*}(E)} d E
# $$
#
# The effective mass has been shown to vary linearly, increasing ~ 20% per $ TW/{cm}^2$ of applied pump intensity
#
# Finally, we can calculate the the permittivity as a function of both $\omega$ and intensity
#
# $$
# \varepsilon(\omega, I)=\varepsilon_{\infty}-\frac{N q^{2}}{\varepsilon_{0} m^{*}_{avg}(I)} \frac{1}{\omega^{2}+i \omega \Gamma}
# $$
#
# where,
# $$\epsilon_{\infty}=\frac{N q^{2}}{\epsilon_{0} m^{*}_{avg}(0)\omega_{p}^2}$$

# %% [markdown]
# ### **Bistability with ENZ waveguide**

# %% [markdown]
# ENZ materials exhibit a dispersion of its relative electrical permitivitty that combines responses of bound ($ ε_{∞} $) and free electrons according to
# $$
# ε(\omega) = ε_{∞} - \frac {ω^{2}_{p}}{\omega^{2} + iω\gamma}
# $$
#
# where $ε_{∞}$ is permittivity due to the bound electrons, $\omega_{p}= (Ne^{2}/ε_{0} m^{*})^{1/2}$ is the plasma frequency, $N$ is the carrier density, $m^{*}$ is the energy (or momentum) dependent effective mass and $\gamma$ is the scattering rate.
#
# The real part of
# permittivity changes from positive to negative at the so-called ENZ frequency $ω_{0}=ω_{p}/ε_{∞}^{1/2}$ (identified as
# screened plasma frequency) with an imaginary part of the permittivity introducing absorption in the
# material.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# </br>
# **Fig 1:** At low optical powers, the ITO Layer is metallic and the optical power density is low. As the power increases (bottom) the real part of permittivity approaches zero
# and the optical power inside multilayered system gets redistributed which shifts Re(ε) even closer to zero,
# thus closing the positive feedback loop and causing switching.

# %% [markdown]
# $$
# ε(\omega) = ε_{∞} - \frac {ω^{2}_{p} \omega^{2}}{\omega^{4} + ω^{2}\gamma ^{2}} + i \frac {ω^{2}_{p} \omega \gamma}{\omega^{4} + ω^{2}\gamma ^{2}}
# $$
#
# Hence
# $$
# ε_{r} = ε_{∞} - \frac {ω^{2}_{p} \omega^{2}}{\omega^{4} + ω^{2}\gamma ^{2}}
# $$
#
# $$
# ε_{i} = \frac {ω^{2}_{p} \omega \gamma}{\omega^{4} + ω^{2}\gamma ^{2}}
# $$
#
# where, $\omega_{p}= (Ne^{2}/ε_{0} m^{*})^{1/2}$
#
# </br>
# We will now compare the behaviour of real and imaginary parts of permittivity.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# </br>Dispersion of real and imaginary parts
# of dielectric permittivity as a function of (c) effective mass and (d) carrier concentration.

# %% [markdown]
# According to boundary conditions for light polarized normal to interface (TM), the displacement *D=εE* is continuous across the interface, and therefore the electric field (and hence the energy density) is much higher in the ENZ material than in the conventional dielectric. If a thin layer of ENZ material is inserted in the slot of a waveguide (which can be photonic or plasmonic), the closer is the wavelength to $ω_{0}$, the higher is the field the slot. This is a well-studied slot waveguide effect that allows subwavelength field confinement in the low permittivity medium, taken to its ultimate $ε$~$0$ limit.
#
# Unlike the dielectric cladding, ENZ material is highly absorptive and as the optical field concentrated inside the slot increases, the absorption increases. At the point of large electric fields, the nonlinear properties of the TCO-based ENZ materials come into play. When light is absorbed by the TCO material, it causes an increase of the electron temperature in the conduction band, that in turn leads to an increase of the effective mass and corresponding rise of the dielectric constant. If the carrier density is such that in the absence of light the real permittivity is $ Re(ε)< 0 $, an increase of $Re(ε)$ would move it closer to zero, which in turn will cause even higher concentration of energy inside the ENZ material layer. Thus, a positive feedback mechanism, essential for bistability, is established. As more energy is concentrated in the ENZ layer, the electron temperature in it rises causing an increase of the dielectric constant and further concentration of energy in the ENZ layer. Obviously, no stable solution can exist with positive feedback and switching occurs.

# %% [markdown]
# We can provide an estimate for the strength and dependence of the nonlinearity by taking a few assumptions in order to obtain an analytical expression for the nonlinear coefficients in the ENZ region. We assume
# that the average effective mass of the electron gas is approximately equal to the effective mass at the Fermi Level,
# $ m^{*} _{avg} ≈ m^{*} (k_{F}) $ , and that the velocity is nearly saturated at the Fermi level, i.e.,
#
#  $$ \frac{dv(k_{F})}{dk} << \frac{v(k_{F})}{ k_{F}} $$

# %% [markdown]
# When electrons absorb a pump photon, their energy changes by some amount  $\delta E_{i}$, which for electrons near the Fermi level produces a change of momentum for the electron of $\delta k_{i} = \delta E_{i} / \hbar v_{F}$ , where $v_{F}$ is the Fermi velocity

# %% [markdown]
#  Given our momentum dependent effective mass, the change in the effective mass due to the
# intraband absorption process is:
#
# $$
# \delta \left(\frac{1}{m^{*}}\right)_{i} = \left(\frac{∂}{∂k} \frac {1}{m^{*}(k)}\right)_{i}\delta k = - \left(\frac{1}{m^{*}(k_{F})}\right) \frac{\delta k_{i}}{k_{F}} = -\left(\frac{1}{m^{*}}\right) \frac{\delta E_{i}}{\hbar v_{F}k_{F}}
# $$

# %% [markdown]
# Although $\delta E_i$, and therefore $\delta k_i$, is different for each electron, the sum of the energy change over all of the electrons within a given volume is equal to $V^{-1}\sum\limits_i\delta E_i=\delta \mathcal{U}_{abs}$, where $\delta \mathcal{U}_{abs}$ is the absorbed energy density of the pump beam. We can then find the total change to the permittivity by summing over the small modifications in the effective mass induced by the excitation of hot electrons which while neglecting loss becomes:
#
# $$\delta 𝜀 \approx -\dfrac{q^2}{𝜀_0 \omega^2} \dfrac{1}{V} \sum\limits_{\delta k} \delta \left(\dfrac{1}{m^*}\right)_i=\dfrac{q^2}{𝜀_0 m^* (k_F)\omega^2}\dfrac{\delta \mathcal{U}_{abs}}{\hbar v_F k_F}$$
#
# and when using the relation $𝜀_{\infty}=Nq^2/(𝜀_0 m^*_{avg}\omega^2_p)$ reduces to:
#
# $$\delta 𝜀(\omega_p) = 𝜀_{\infty}\dfrac{\delta\mathcal{U}_{abs}}{N\hbar v_F k_F}$$
#
# at the screened plasma frequency.
#
# Note that $\delta\mathcal{U}_{abs}$ is same as  $\mathcal{U}_{hot}$ which is the energy density transfered to the hot carriers in the ITO.

# %% [markdown]
# Thus using the above equations we get,
# $$ \frac{\delta m^{*}}{m^{*}} = \dfrac{\mathcal{U}_{hot}}{N\hbar v_F k_F}$$

# %% [markdown]
# Using the relation between plasma frequency and effective mass, we get
#
# $$
# \frac{\delta m^{*}} {m^{*}} = -\frac{\delta ω^{2}_{p}}{ω^{2}_{p}} = \dfrac{\mathcal{U}_{hot}}{N\hbar v_F k_F}
# $$

# %% [markdown]
# For an optical power P in the waveguide, the absorbed power density in the ITO filled slot is $ \mathcal{U}_{hot} = P_{abs} τ = \alpha P \tau/ S_{ITO}$, where $\tau$ is the "cooling time", i.e., the time it takes to transfer energy from the hot carriers to the lattice via electron-phonon scattering.

# %% [markdown]
# For the sake of simplification, we assume that $ħk_{F}\nu_{F} ≈E_{F}$ which is physically valid – in order to change the effective mass $\mathcal{U}_{hot}$ of each electron in an assembly of $N$ electrons, the change of energy of each electron $\mathcal{U}_{hot}/N$ should be noticeable relative to the energy it already had, i.e., roughly Fermi energy. We then obtain the following linearized relation between the absorption coefficient, plasma frequency and power.
# $$
# ω^{2}_{p} = ω^{2}_{p_0} - ω^{2}_{p_0} \frac{\alpha \tau}{NE_{F}S} P
# $$
# Where $ω_{p0}$ is the plasma frequency in the absence of optical power and heating.

# %% [markdown]
# # Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import host_subplot

# %%
# !gdown 1N_fJJ1G4rjpBCLuAR-ghEMsZIULqiYD9  #downloading plot data from simulation
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1N_fJJ1G4rjpBCLuAR-ghEMsZIULqiYD9
# To: /content/plot_data.npy
# 100% 6.21k/6.21k [00:00<00:00, 8.53MB/s]

# %%
plot_data = np.load('/content/plot_data.npy')

# %%
def plasma_frequency1(n, m, e, eps0, me):
    return np.sqrt(n*e**2/(eps0*me))

def alpha(pf2, power):
    pf02 = 10e30             #from the plot in paper, have to verify, plasma frequency^2 in absence of optical power and heating
    t = 100*1e-15           #colling time, few hundred femtoseconds
    N = 8*1e26              #Carrier density, 8*10^26 m^-3
    ef = 4.5                #fermi energy, 4.5 eV
    efw = ef*1.60217733*1e-19   #fermi energy in joules
    s = (400*1e-9)*(10e-9)  #Cross section of ITO layer, 400nm*10nm, from paper
    return (1 - (pf2/pf02))*(N*efw*s/(t*power))*(1e-6)   #alpha in um^-1

# %%
pf = np.arange(0, 11e30, 1e30)
ax = host_subplot(111)
for i in [6, 3.8,2.2, 1.8,1.2, 2.6, 1.45]:
    power = i
    ax.plot(pf, alpha(pf, power), label = i)  #, label = 'Power = ' + str(power) + 'W'


ax.plot(plot_data[0,:], plot_data[1,:], label = r'$\alpha = F( \omega _p ^2)$', color = 'black')
ax.set_xlabel('Plasma Frequency')
ax.set_ylabel('Mode attenuation (1/'+r'$\mu m$'+')')
# ax.set_title('Mode attenuation vs Plasma Frequency')
ax.set_xlim(0.2e31, 10e30)
ax.set_ylim(0, 7)
ax.legend()
ax2 = ax.twin()
tick_val = np.arange(0, 1, 1/10)*1e31
w = 2*np.pi*3e8/1330e-9   #angular frequency for 1500nm 
er = 2.68 - (tick_val/w**2)
er = np.round(er, 2)
ax2.set_xticks(tick_val)
ax2.set_xticklabels(er)
ax2.set_xlabel('Permitivity ' + r'$\epsilon _r$')

plt.show()

# %%
def intersection_points(power):
    th = 0.1
    th2 = 0.1
    x0 = plot_data[0,:]
    y0 = plot_data[1,:]
    y = alpha(x0, power)
    dy = y0 - y
    idx = np.argwhere((-1*th < dy) * (dy < 1*th))
    y_temp = y0[idx]
    y2 = np.zeros((len(y_temp), 1))
    y2[1:] = y_temp[:-1]
    diff = y_temp - y2
    # print(diff.max(), diff.min())
    idx_f = np.argwhere((diff > th2) + (diff < -1*th2) )[:,0]
    # print(idx_f)
    return (x0[idx])[idx_f], (y0[idx])[idx_f], y, x0

# %% [markdown]
# ![alpha_pow (1).gif](data:image/gif;base64,...)

# %%
pt_start = 0.4
pt_end = 15
pt_step = 0.01
powers = np.arange(pt_start, pt_end, pt_step)
alpha_arr_max = []
for power in powers:
    a, b, y, x = intersection_points(power)
    b = np.array(b)
    alpha_arr_max.append([power, b.max()])

plt.plot(powers, np.array(alpha_arr_max)[:,1])
alpha_arr_min = []
for power in powers:
    a, b, y, x = intersection_points(power)
    b = np.array(b)
    alpha_arr_min.append([power, b.min()])


plt.plot(powers, np.array(alpha_arr_min)[:,1])
plt.xlabel('Power (W)')
plt.ylabel('Mode attenuation (1/'+r'$\mu m$'+')')
plt.title('Mode attenuation vs Power')
plt.show()

# %% [markdown]
# $$\alpha (z) = \alpha (P(z))$$
# $$\frac{dP(z)}{dz} = - \alpha (z) P(z)$$
# ## Boundary Condition
# $P(0) = P(in)$ \\
# $ L = 1 \mu m$

# %% [markdown]
# $ $

# %%
class slab:
    def __init__(self, alpha_max, alpha_min, power_data):
        self.l = 1e-6
        self.dz = 1e-8
        self.alpha = np.zeros(int(self.l/self.dz))
        self.power = np.zeros(int(self.l/self.dz))
        self.alpha_arr_max = np.array(alpha_max)
        self.alpha_arr_min = np.array(alpha_min)
        self.power_data = np.array(power_data)
        self.last_p = 0

    def calc_alpha(self, power, p_up = True):
        idx = np.argmin(np.abs(self.power_data - power))
        try:
            if len(idx) > 1:
                idx = idx[0]
        except:
            pass

        if p_up :
            return self.alpha_arr_max[idx, 1]
        else:
            return self.alpha_arr_min[idx, 1]

    def update_power(self):
        self.alpha = np.array([self.calc_alpha(self.power[idx], self.p_up) for idx in range(len(self.power))])
        self.power = self.power - self.alpha*self.power*self.dz/1e-6
        self.power[self.power < 0] = 0

    def propgate(self, p_in):
        last_power = np.copy(self.power)
        self.power[1:] = self.power[:-1]
        self.power[0] = p_in
        # print(self.power)
        self.p_up = (p_in - self.last_p ) < 0
        # print(len(np.argwhere(self.p_up == True)))

    def update(self, p_in):
        self.propgate(p_in)
        self.update_power()

    def out(self,p_in):
        for i in range(len(self.power)):
            self.update(p_in)
        self.last_p = p_in
        return self.power[-1]

# %%
s = slab(alpha_arr_max, alpha_arr_min, powers)
out = [s.out(p) for p in np.arange(powers.min(), powers.max(), 0.3)]

# %%
plt.plot(np.arange(powers.min(), powers.max(), 0.3), out)

# %%
s = slab(alpha_arr_max, alpha_arr_min, powers)
out1 = [s.out(p) for p in np.arange(powers.max(), powers.min(), -0.3)]

# %%
plt.plot(np.arange(powers.max(), powers.min(), -0.3), out1)

# %%
plt.plot(np.arange(powers.max(), powers.min(), -0.3), out1, label = 'Power Down')
plt.plot(np.arange(powers.min(), powers.max(), 0.3), out, label = 'Power UP')
plt.legend()
plt.xlabel('Power IN')
plt.ylabel('Power OUT')
plt.show()

# %% [markdown]
# # Bistable ENZ device in Neural Networks

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.np_utils import to_categorical
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
class ENZ_act(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(ENZ_act, self).__init__(**kwargs)
        self.block_1 = 0
        self.block_2 = 2.4
        self.block_3 = 6.9
        self.slop_1 = 0
        self.slop_2 = 0.6
        self.slop_3 = 0.21
        self.slop_4 = 0.5
        self.intercept_3 = 0.95
        self.intercept_4 = -1.05
    
    def build(self, input_shape):
        return super().build(input_shape)
    
    def call(self, x):
        return tf.where(x<self.block_1, tf.multiply(x, self.slop_1), 
               tf.where(x<self.block_2, tf.multiply(x, self.slop_2),
               tf.where(x<self.block_3, tf.add(tf.multiply(x, self.slop_3), self.intercept_3),tf.add(tf.multiply(x, self.slop_4), self.intercept_4))))

# %%
#plot of activation function derived from ENZ material behaviour
enz = ENZ_act()
a = tf.constant(np.arange(-10, 10, 0.1), dtype = tf.float32)
plt.plot(a, enz(a))
plt.xlabel('Input')
plt.ylabel('Output')
plt.show()

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
train_data = np.expand_dims(x_train, -1)
test_data = np.expand_dims(x_test, -1)


# convert class vectors to binary class matrices
train_label = to_categorical(y_train, num_classes)
test_label = to_categorical(y_test, num_classes)
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#MNIST relu
act = 'relu'
epochs = 30
input_shape=(28,28,1)
model = tf.keras.Sequential(
    [
        tf.keras.Input(shape=input_shape),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(400,activation=act),
        tf.keras.layers.Dense(200,activation=act),

        tf.keras.layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history_MNIST_Relu=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label),verbose=0)



test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 400)               314000
#
#  dense_1 (Dense)             (None, 200)               80200
#
#  dense_2 (Dense)             (None, 10)                2010
#
# ...
# Total params: 396,210
# Trainable params: 396,210
# Non-trainable params: 0
# _________________________________________________________________
# 313/313 [==============================] - 1s 2ms/step

# %%
#MNIST sigmoid
act = 'sigmoid'
epochs = 30
input_shape=(28,28,1)
model = tf.keras.Sequential(
    [
        tf.keras.Input(shape=input_shape),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(400,activation=act),
        tf.keras.layers.Dense(200,activation=act),

        tf.keras.layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history_MNIST_Sigmoid=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label),verbose=0)



test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_3 (Dense)             (None, 400)               314000
#
#  dense_4 (Dense)             (None, 200)               80200
#
#  dense_5 (Dense)             (None, 10)                2010
#
# ...
# Total params: 396,210
# Trainable params: 396,210
# Non-trainable params: 0
# _________________________________________________________________
# 313/313 [==============================] - 1s 2ms/step

# %%
#MNIST ENZ activation
epochs = 30
input_shape=(28,28,1)
model = tf.keras.Sequential(
    [
        tf.keras.Input(shape=input_shape),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(400),
        ENZ_act(),
        tf.keras.layers.Dense(200),
        ENZ_act(),

        tf.keras.layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history_MNIST_Bistable=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label),verbose=0)



test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 400)               314000
#
#  enz_act_1 (ENZ_act)         (None, 400)               0
#
#  dense_7 (Dense)             (None, 200)               80200
#
#  enz_act_2 (ENZ_act)         (None, 200)               0
#
#  dense_8 (Dense)             (None, 10)                2010
#
# ...
# Total params: 396,210
# Trainable params: 396,210
# Non-trainable params: 0
# _________________________________________________________________
# 313/313 [==============================] - 1s 2ms/step

# %%
tf.keras.utils.plot_model(model)

# %%
#MNIST no activation
input_shape=(28,28,1)
epochs = 30
model = tf.keras.Sequential(
    [
        tf.keras.Input(shape=input_shape),
        tf.keras.layers.Flatten(),
        #layers.Dense(200,activation=tf.keras.activations.sigmoid),
        tf.keras.layers.Dense(400),
        tf.keras.layers.Dense(200),
        tf.keras.layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history_MNIST_No=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label),verbose=0)

test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_3 (Flatten)         (None, 784)               0
#
#  dense_9 (Dense)             (None, 400)               314000
#
#  dense_10 (Dense)            (None, 200)               80200
#
#  dense_11 (Dense)            (None, 10)                2010
#
# ...
# Total params: 396,210
# Trainable params: 396,210
# Non-trainable params: 0
# _________________________________________________________________
# 313/313 [==============================] - 0s 1ms/step

# %%
#Plot accuracy vs epochs 
plt.plot(history_MNIST_Relu.history['val_accuracy'])
plt.plot(history_MNIST_Sigmoid.history['val_accuracy'])
plt.plot(history_MNIST_Bistable.history['val_accuracy'])
plt.plot(history_MNIST_No.history['val_accuracy'])
plt.title('model accuracy with different activation function for MNIST')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['ReLu', 'Sigmoid','Bistable nonlinear','Linear'], loc='center right')
plt.show()


plt.plot(history_MNIST_Relu.history['val_loss'])
plt.plot(history_MNIST_Sigmoid.history['val_loss'])
plt.plot(history_MNIST_Bistable.history['val_loss'])
plt.plot(history_MNIST_No.history['val_loss'])
plt.title('model loss with different activation function for MNIST')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['ReLu', 'Sigmoid','Bistable nonlinear','Linear'], loc='center right')
plt.show()

print(history_MNIST_Relu.history['val_accuracy'][29],history_MNIST_Relu.history['val_loss'][29])
print(history_MNIST_Sigmoid.history['val_accuracy'][29],history_MNIST_Sigmoid.history['val_loss'][29])
print(history_MNIST_Bistable.history['val_accuracy'][29],history_MNIST_Bistable.history['val_loss'][29])
print(history_MNIST_No.history['val_accuracy'][29],history_MNIST_No.history['val_loss'][29])
# Out:
# 0.9843000173568726 0.09055390954017639
# 0.9818999767303467 0.0785059779882431
# 0.9839000105857849 0.07523009926080704
# 0.9240000247955322 0.2828766405582428

# %% [markdown]
# ## Conclusions
# In this work we have proposed and analyzed a novel bistable device based on ENZ material in a slot waveguide and have shown that it shows high nonlinearity and significant bistability without optical cavity. Small space it takes and high switching speed of the proposed device can lead to applications in various all-optical systems including neural networks where the performance of the devices was estimated and found to be excellent.

# %% [markdown]
# # Contribution
# 200260012 Ayush Raj Tarway :  Formulized the dependence of permitivity and effective mass wrt Intensity, formulised relation between absorption cofficient, plasma frequency and power
#
# 200260016 Dosapati Jayanth : Explored ENZ material in general and Stuided $\chi ^{(3)}$ , reflective Index and $ϵ $
#
# 200260027 Mahesh Bhupati : Understanding the whole pipeline to generate plots from equation and Simulation, Used Pin vs Pout in ML model as activation Layer
#
# 200260043 Rupansh Parth Kaushik : ENZ matterial formlization, Explored and formulaized Momentum dependent effective mass and Drude formula, Used Pin vs Pout in ML model as activation Layer
#
# 200260052 Shreyas Patil : Formulized relation between change in effective mass, plasma frequency and it's dependence on energy, and formulised relation between absorption cofficient, plasma frequency and power
